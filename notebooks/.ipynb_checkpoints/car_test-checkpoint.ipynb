# %%
SIMULATION = True

# %%
import sys
import os
import time
import math

import cv2
import numpy as np

if SIMULATION: 
    from simulation import rospy
    from simulation.sensor_msgs.msg import LaserScan, Image
    from simulation.jetracer.nvidia_racecar import NvidiaRacecar
else:
    import rospy
    from sensor_msgs.msg import LaserScan, Image
    from jetracer.nvidia_racecar import NvidiaRacecar

# %%
car = NvidiaRacecar()
