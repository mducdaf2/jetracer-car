# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import time
import math

import cv2
import numpy as np

import rospy
from sensor_msgs.msg import LaserScan, Image
from jetracer.nvidia_racecar import NvidiaRacecar
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       6 import cv2
#       7 import numpy as np
# ----> 9 import rospy
#      10 from sensor_msgs.msg import LaserScan, Image
#      11 from jetracer.nvidia_racecar import NvidiaRacecar
#
# ModuleNotFoundError: No module named 'rospy'

# %%
car = NvidiaRacecar()
